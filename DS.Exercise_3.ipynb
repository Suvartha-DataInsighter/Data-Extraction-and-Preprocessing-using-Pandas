# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (0.11.2)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\SOORI\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy>=1.0 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.22.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (1.4.0)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (4.29.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\soori\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
import seaborn as sns

# %%
df=sns.load_dataset("tips")

# %% [markdown]
# ### How much each value of total_bill is far from its mean?

# %%
df["total_bill"].mean()-df["total_bill"]
# Out:
# 0      2.795943
# 1      9.445943
# 2     -1.224057
# 3     -3.894057
# 4     -4.804057
#          ...
# 239   -9.244057
# 240   -7.394057
# 241   -2.884057
# 242    1.965943
# 243    1.005943
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
#    ### Can you take random sample of 50 observations without changing its state from this data

# %%
df.sample(50,random_state=20)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 87        18.28  4.00    Male     No  Thur   Lunch     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 128       11.38  2.00  Female     No  Thur   Lunch     2
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 129       22.82  2.18    Male     No  Thur   Lunch     3
# 132       11.17  1.50  Female     No  Thur   Lunch     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# 163       13.81  2.00    Male     No   Sun  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 59        48.27  6.73    Male     No   Sat  Dinner     4
# 34        17.78  3.27    Male     No   Sat  Dinner     2
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 147       11.87  1.63  Female     No  Thur   Lunch     2
# 111        7.25  1.00  Female     No   Sat  Dinner     1
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 158       13.39  2.61  Female     No   Sun  Dinner     2
# 151       13.13  2.00    Male     No   Sun  Dinner     2
# 89        21.16  3.00    Male     No  Thur   Lunch     2
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 140       17.47  3.50  Female     No  Thur   Lunch     2
# 106       20.49  4.06    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2
# 119       24.08  2.92  Female     No  Thur   Lunch     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 212       48.33  9.00    Male     No   Sat  Dinner     4
# 117       10.65  1.50  Female     No  Thur   Lunch     2
# 95        40.17  4.73    Male    Yes   Fri  Dinner     4
# 152       17.26  2.74    Male     No   Sun  Dinner     3
# 77        27.20  4.00    Male     No  Thur   Lunch     4
# 167       31.71  4.50    Male     No   Sun  Dinner     4
# 66        16.45  2.47  Female     No   Sat  Dinner     2
# 91        22.49  3.50    Male     No   Fri  Dinner     2

# %% [markdown]
# ### Randomly pick 10 observations of total_bill with certain randomstate and return its highest total_bill value.Repeat the process for 10 times and find its average value

# %%
sum=0
for i in range(10):
    random_pick=df.sample(10).total_bill.max()
    sum+=random_pick
print("average:",sum/10)
# Out:
# average: 34.626

# %% [markdown]
# ### Create the synthetic data for total bill and tip with size of 2. Write code to generate values in between 50 and 100 for total_bill AND tip in between 10 and 20 dollars. Plot the newly generated data to see if these two new variables are correlated? and discuss the same.

# %%
df["total_new_bill"]=df["total_bill"]*2
df["new_tip"]=df["tip"]*2
df[(df["total_bill"]>=50) & (df["total_bill"]<=100)]
df[(df["tip"]>=10 )& (df["tip"]<=20)]
df[df["size"]==2]
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_new_bill  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2           33.98
# 3         23.68  3.31    Male     No   Sun  Dinner     2           47.36
# 6          8.77  2.00    Male     No   Sun  Dinner     2           17.54
# 8         15.04  1.96    Male     No   Sun  Dinner     2           30.08
# 9         14.78  3.23    Male     No   Sun  Dinner     2           29.56
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2           65.66
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2           54.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           45.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2           35.64
# 243       18.78  3.00  Female     No  Thur  Dinner     2           37.56
#
#      new_tip
# 0       2.02
# 3       6.62
# 6       4.00
# 8       3.92
# 9       6.46
# ..       ...
# 237     2.34
# 240     4.00
# 241     4.00
# 242     3.50
# 243     6.00
#
# [156 rows x 9 columns]

# %%
sns.regplot(y="total_new_bill",x="new_tip",data=df,color="green")
# Out:
# <AxesSubplot:xlabel='new_tip', ylabel='total_new_bill'>

# %% [markdown]
# #### There is a Positive Relationship between Total_new_bill and New_tip

# %% [markdown]
# ### Identify the data where total_bill and tip values are having atleast 10 dollors difference

# %%
df["total_amount"]=df["total_bill"]-df["tip"]
df[df["total_amount"]>=10]
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_new_bill  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2           33.98
# 2         21.01  3.50    Male     No   Sun  Dinner     3           42.02
# 3         23.68  3.31    Male     No   Sun  Dinner     2           47.36
# 4         24.59  3.61  Female     No   Sun  Dinner     4           49.18
# 5         25.29  4.71    Male     No   Sun  Dinner     4           50.58
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3           58.06
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2           54.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2           45.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2           35.64
# 243       18.78  3.00  Female     No  Thur  Dinner     2           37.56
#
#      new_tip  total_amount
# 0       2.02         15.98
# 2       7.00         17.51
# 3       6.62         20.37
# 4       7.22         20.98
# 5       9.42         20.58
# ..       ...           ...
# 239    11.84         23.11
# 240     4.00         25.18
# 241     4.00         20.67
# 242     3.50         16.07
# 243     6.00         15.78
#
# [203 rows x 10 columns]

# %% [markdown]
# ### Why friday is most typical day for better transaction? pleease discuss in detail

# %%
df.groupby("day")["total_bill"].mean()
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %% [markdown]
# #### The Friday is most typical day for transaction because there is less presence of customers,so we get less average of total_bill

# %% [markdown]
# ### Randomly pick a total_bill value from 0-50 and return the highest among the list.And repeat the process for atleast 5 times and identify which are closest values

# %%
a=df[(df["total_bill"]>=0)&(df["total_bill"]<=10)].sample(10).max()
print(a)
b=df[(df["total_bill"]>=11)&(df["total_bill"]<=20)].sample(10).max()
print(b)
c=df[(df["total_bill"]>=21)&(df["total_bill"]<=30)].sample(10).max()
print(c)
d=df[(df["total_bill"]>=31)&(df["total_bill"]<=40)].sample(10).max()
print(d)
e=df[(df["total_bill"]>=41)&(df["total_bill"]<=50)].sample(10).max()
print(e)
# Out:
# C:\Users\SOORI\AppData\Local\Temp/ipykernel_1700/2882640662.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a=df[(df["total_bill"]>=0)&(df["total_bill"]<=10)].sample(10).max()
# C:\Users\SOORI\AppData\Local\Temp/ipykernel_1700/2882640662.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   b=df[(df["total_bill"]>=11)&(df["total_bill"]<=20)].sample(10).max()
# C:\Users\SOORI\AppData\Local\Temp/ipykernel_1700/2882640662.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   c=df[(df["total_bill"]>=21)&(df["total_bill"]<=30)].sample(10).max()
# C:\Users\SOORI\AppData\Local\Temp/ipykernel_1700/2882640662.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   d=df[(df["total_bill"]>=31)&(df["total_bill"]<=40)].sample(10).max()
# total_bill         9.78
# tip                4.00
# size               2.00
# total_new_bill    19.56
# new_tip            8.00
# total_amount       8.10
# dtype: float64
# total_bill        19.82
# tip                3.50
# size               3.00
# total_new_bill    39.64
# new_tip            7.00
# total_amount      17.28
# dtype: float64
# total_bill        29.93
# tip                5.07
# size               6.00
# total_new_bill    59.86
# new_tip           10.14
# total_amount      24.86
# dtype: float64
# total_bill        39.42
# tip                7.58
# size               6.00
# total_new_bill    78.84
# new_tip           15.16
# total_amount      34.07
# dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1700/2882640662.py in <module>
#       7 d=df[(df["total_bill"]>=31)&(df["total_bill"]<=40)].sample(10).max()
#       8 print(d)
# ----> 9 e=df[(df["total_bill"]>=41)&(df["total_bill"]<=50)].sample(10).max()
#      10 print(e)
#      11
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5452             weights = sample.preprocess_weights(self, weights, axis)
#    5453
# -> 5454         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5455         result = self.take(sampled_indices, axis=axis)
#    5456
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\sample.py in sample(obj_len, size, replace, weights, random_state)
#     148             raise ValueError("Invalid weights: weights sum to zero")
#     149
# --> 150     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     151         np.intp, copy=False
#     152     )
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %% [markdown]
# ### Make a group of total_bills data from the random sample of bills data the random sample of 20observations and find its list of closest values

# %%
df_48=df["total_bill"].sample(20)
list1=list(df_48.sort_values())
print(list(list1))

# %%
x=df["total_bill"].sample(20,random_state=20)
print(x)
print("____________________________________________________")
a=x.head(10).tail(5)
print(a)
print("____________________________________________________")
b=x.tail(10).head(5)
print(b)
print("____________________________________________________")
c=x.head(5).tail(10)
print(c)
print("____________________________________________________")
d=x.head(5).head(10)
print(d)
print("____________________________________________________")
input=17
df.iloc[(df["total_bill"]-input).abs().argsort()[:2]]

# %% [markdown]
# ### Discuss your ideology and critics of why female has less smoking data compare to male

# %%
a=df[(df["smoker"]=="Yes")&(df["sex"]=="Female")]
len(a)

# %%
b=df[(df["smoker"]=="Yes")&(df["sex"]=="Male")]
len(b)

# %%
df[df["smoker"]=="Yes"]["sex"].value_counts()

# %% [markdown]
# #####  Compared to Male and Female the gender female has very smoking data...Because the male % in every aspect is more than female and with smoking we have got very less data

# %% [markdown]
# ### Randomly pick a record from this dataset and return its Gender with total_bill and tip values.Repeat process for at least for 5 times and return highest among them

# %%
l=[]
for i in range(5):
    s=df.sample()[["sex","total_bill","tip"]]
    l.append(s)
#print(max(l))
l

# %% [markdown]
# #### The male has return highest total_bill and tip
